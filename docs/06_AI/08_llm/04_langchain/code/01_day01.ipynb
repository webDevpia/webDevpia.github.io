# %%
# %pip install langchain langchain-openai python-dotenv
# Out:
# Requirement already satisfied: langchain in /opt/homebrew/anaconda3/envs/langchain_part_1/lib/python3.12/site-packages (0.3.25)
# Requirement already satisfied: langchain-openai in /opt/homebrew/anaconda3/envs/langchain_part_1/lib/python3.12/site-packages (0.3.18)
# Requirement already satisfied: python-dotenv in /opt/homebrew/anaconda3/envs/langchain_part_1/lib/python3.12/site-packages (1.1.0)
# Requirement already satisfied: langchain-core<1.0.0,>=0.3.58 in /opt/homebrew/anaconda3/envs/langchain_part_1/lib/python3.12/site-packages (from langchain) (0.3.61)
# Requirement already satisfied: langchain-text-splitters<1.0.0,>=0.3.8 in /opt/homebrew/anaconda3/envs/langchain_part_1/lib/python3.12/site-packages (from langchain) (0.3.8)
# Requirement already satisfied: langsmith<0.4,>=0.1.17 in /opt/homebrew/anaconda3/envs/langchain_part_1/lib/python3.12/site-packages (from langchain) (0.3.42)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in /opt/homebrew/anaconda3/envs/langchain_part_1/lib/python3.12/site-packages (from langchain) (2.11.5)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in /opt/homebrew/anaconda3/envs/langchain_part_1/lib/python3.12/site-packages (from langchain) (2.0.41)
# Requirement already satisfied: requests<3,>=2 in /opt/homebrew/anaconda3/envs/langchain_part_1/lib/python3.12/site-packages (from langchain) (2.32.3)
# Requirement already satisfied: PyYAML>=5.3 in /opt/homebrew/anaconda3/envs/langchain_part_1/lib/python3.12/site-packages (from langchain) (6.0.2)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in /opt/homebrew/anaconda3/envs/langchain_part_1/lib/python3.12/site-packages (from langchain-core<1.0.0,>=0.3.58->langchain) (9.1.2)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in /opt/homebrew/anaconda3/envs/langchain_part_1/lib/python3.12/site-packages (from langchain-core<1.0.0,>=0.3.58->langchain) (1.33)
# Requirement already satisfied: packaging<25,>=23.2 in /opt/homebrew/anaconda3/envs/langchain_part_1/lib/python3.12/site-packages (from langchain-core<1.0.0,>=0.3.58->langchain) (24.2)
# Requirement already satisfied: typing-extensions>=4.7 in /opt/homebrew/anaconda3/envs/langchain_part_1/lib/python3.12/site-packages (from langchain-core<1.0.0,>=0.3.58->langchain) (4.13.2)
# Requirement already satisfied: jsonpointer>=1.9 in /opt/homebrew/anaconda3/envs/langchain_part_1/lib/python3.12/site-packages (from jsonpatch<2.0,>=1.33->langchain-core<1.0.0,>=0.3.58->langchain) (3.0.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /opt/homebrew/anaconda3/envs/langchain_part_1/lib/python3.12/site-packages (from langsmith<0.4,>=0.1.17->langchain) (0.28.1)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in /opt/homebrew/anaconda3/envs/langchain_part_1/lib/python3.12/site-packages (from langsmith<0.4,>=0.1.17->langchain) (3.10.18)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in /opt/homebrew/anaconda3/envs/langchain_part_1/lib/python3.12/site-packages (from langsmith<0.4,>=0.1.17->langchain) (1.0.0)
# Requirement already satisfied: zstandard<0.24.0,>=0.23.0 in /opt/homebrew/anaconda3/envs/langchain_part_1/lib/python3.12/site-packages (from langsmith<0.4,>=0.1.17->langchain) (0.23.0)
# Requirement already satisfied: anyio in /opt/homebrew/anaconda3/envs/langchain_part_1/lib/python3.12/site-packages (from httpx<1,>=0.23.0->langsmith<0.4,>=0.1.17->langchain) (4.9.0)
# Requirement already satisfied: certifi in /opt/homebrew/anaconda3/envs/langchain_part_1/lib/python3.12/site-packages (from httpx<1,>=0.23.0->langsmith<0.4,>=0.1.17->langchain) (2025.4.26)
# Requirement already satisfied: httpcore==1.* in /opt/homebrew/anaconda3/envs/langchain_part_1/lib/python3.12/site-packages (from httpx<1,>=0.23.0->langsmith<0.4,>=0.1.17->langchain) (1.0.9)
# Requirement already satisfied: idna in /opt/homebrew/anaconda3/envs/langchain_part_1/lib/python3.12/site-packages (from httpx<1,>=0.23.0->langsmith<0.4,>=0.1.17->langchain) (3.10)
# Requirement already satisfied: h11>=0.16 in /opt/homebrew/anaconda3/envs/langchain_part_1/lib/python3.12/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<0.4,>=0.1.17->langchain) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /opt/homebrew/anaconda3/envs/langchain_part_1/lib/python3.12/site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /opt/homebrew/anaconda3/envs/langchain_part_1/lib/python3.12/site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /opt/homebrew/anaconda3/envs/langchain_part_1/lib/python3.12/site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.4.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in /opt/homebrew/anaconda3/envs/langchain_part_1/lib/python3.12/site-packages (from requests<3,>=2->langchain) (3.4.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/homebrew/anaconda3/envs/langchain_part_1/lib/python3.12/site-packages (from requests<3,>=2->langchain) (2.4.0)
# Requirement already satisfied: openai<2.0.0,>=1.68.2 in /opt/homebrew/anaconda3/envs/langchain_part_1/lib/python3.12/site-packages (from langchain-openai) (1.82.0)
# Requirement already satisfied: tiktoken<1,>=0.7 in /opt/homebrew/anaconda3/envs/langchain_part_1/lib/python3.12/site-packages (from langchain-openai) (0.9.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /opt/homebrew/anaconda3/envs/langchain_part_1/lib/python3.12/site-packages (from openai<2.0.0,>=1.68.2->langchain-openai) (1.9.0)
# Requirement already satisfied: jiter<1,>=0.4.0 in /opt/homebrew/anaconda3/envs/langchain_part_1/lib/python3.12/site-packages (from openai<2.0.0,>=1.68.2->langchain-openai) (0.10.0)
# Requirement already satisfied: sniffio in /opt/homebrew/anaconda3/envs/langchain_part_1/lib/python3.12/site-packages (from openai<2.0.0,>=1.68.2->langchain-openai) (1.3.1)
# Requirement already satisfied: tqdm>4 in /opt/homebrew/anaconda3/envs/langchain_part_1/lib/python3.12/site-packages (from openai<2.0.0,>=1.68.2->langchain-openai) (4.67.1)
# Requirement already satisfied: regex>=2022.1.18 in /opt/homebrew/anaconda3/envs/langchain_part_1/lib/python3.12/site-packages (from tiktoken<1,>=0.7->langchain-openai) (2024.11.6)
# Note: you may need to restart the kernel to use updated packages.

# %%
from dotenv import load_dotenv
load_dotenv()  # .env 파일의 내용 환경 변수로 로드

import os
if os.getenv("OPENAI_API_KEY"):
    print("API key loaded successfully!")
else:
    print("Error: OpenAI API key not found. Please check .env file.")
# Out:
# API key loaded successfully!

# %%
from langchain_core.prompts import PromptTemplate

# 프롬프트 템플릿 정의: {product} 부분이 이후에 채워질 플레이스홀더입니다.
template = "What is a good name for a company that makes {product}?"
prompt = PromptTemplate.from_template(template)

# 템플릿에 값을 채워 실제 프롬프트 생성
formatted_prompt = prompt.format(product="coffee")
print(formatted_prompt)
# Out:
# What is a good name for a company that makes coffee?

# %%
from langchain_core.prompts import PromptTemplate

template = "{product}를 만드는 회사의 이름으로 어떤 것이 좋을까?"
prompt = PromptTemplate.from_template(template)
formatted_template = prompt.format(product="커피")
print(formatted_template)
# Out:
# 커피를 만드는 회사의 이름으로 어떤 것이 좋을까?

# %%
from langchain_openai import ChatOpenAI

# OpenAI 챗 모델 래퍼 생성 (GPT-4o-mini 모델 사용, 온도=0으로 설정하여 결정론적 응답)
llm = ChatOpenAI(model="gpt-4o-mini", temperature=0)

# 예시 메시지를 모델에 보내보기 (역할: human, 내용: 인사말)
response = llm.invoke([("human", formatted_template)])
print(response)
# Out:
# content='커피를 만드는 회사의 이름으로 다음과 같은 아이디어를 고려해보세요:\n\n1. **모카하우스 (Mocha House)**  \n2. **에스프레소 블렌드 (Espresso Blend)**  \n3. **카페리안 (Caffelian)**  \n4. **브루앤바이브 (Brew & Vibe)**  \n5. **커피스톤 (Coffiston)**  \n6. **아로마틱스 (Aromatics)**  \n7. **빈스파크 (BeanSpark)**  \n8. **더블샷 코퍼레이션 (DoubleShot Corporation)**  \n9. **그라인드 & 그루브 (Grind & Groove)**  \n10. **로스티드 하모니 (Roasted Harmony)**\n\n이름을 정할 때는 타겟 고객층, 브랜드 이미지, 그리고 기억하기 쉬운지 여부도 고려해보세요. 더 구체적인 컨셉이나 방향이 있다면 알려주시면 맞춤 추천도 도와드릴 수 있습니다!' additional_kwargs={'refusal': None} response_metadata={'token_usage': {'completion_tokens': 224, 'prompt_tokens': 21, 'total_tokens': 245, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-mini-2025-04-14', 'system_fingerprint': 'fp_eede8f0d45', 'id': 'chatcmpl-BadkizqcH4LLKN9F6OU6FuGyImTye', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None} id='run--8edd7e50-0056-43e8-a9ec-2e87d73d1e42-0' usage_metadata={'input_tokens': 21, 'output_tokens': 224, 'total_tokens': 245, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}

# %%
from langchain_core.output_parsers import StrOutputParser

parser = StrOutputParser()
parsed_text = parser.invoke(response)  # ChatOpenAI의 응답 객체를 파싱
print(parsed_text)
# Out:
# 커피를 만드는 회사의 이름으로 다음과 같은 아이디어를 고려해보세요:
#
# 1. **모카하우스 (Mocha House)**
# 2. **에스프레소 블렌드 (Espresso Blend)**
# 3. **카페리안 (Caffelian)**
# 4. **브루앤바이브 (Brew & Vibe)**
# 5. **커피스톤 (Coffiston)**
# 6. **아로마틱스 (Aromatics)**
# 7. **빈스파크 (BeanSpark)**
# 8. **더블샷 코퍼레이션 (DoubleShot Corporation)**
# 9. **그라인드 & 그루브 (Grind & Groove)**
# 10. **로스티드 하모니 (Roasted Harmony)**
#
# 이름을 정할 때는 타겟 고객층, 브랜드 이미지, 그리고 기억하기 쉬운지 여부도 고려해보세요. 더 구체적인 컨셉이나 방향이 있다면 알려주시면 맞춤 추천도 도와드릴 수 있습니다!

# %%
print(response.usage_metadata)
# Out:
# {'input_tokens': 21, 'output_tokens': 224, 'total_tokens': 245, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}

# %%
# %pip install langchain_community
# Out:
# Requirement already satisfied: langchain_community in /opt/homebrew/anaconda3/envs/langchain_part_1/lib/python3.12/site-packages (0.3.24)
# Requirement already satisfied: langchain-core<1.0.0,>=0.3.59 in /opt/homebrew/anaconda3/envs/langchain_part_1/lib/python3.12/site-packages (from langchain_community) (0.3.61)
# Requirement already satisfied: langchain<1.0.0,>=0.3.25 in /opt/homebrew/anaconda3/envs/langchain_part_1/lib/python3.12/site-packages (from langchain_community) (0.3.25)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in /opt/homebrew/anaconda3/envs/langchain_part_1/lib/python3.12/site-packages (from langchain_community) (2.0.41)
# Requirement already satisfied: requests<3,>=2 in /opt/homebrew/anaconda3/envs/langchain_part_1/lib/python3.12/site-packages (from langchain_community) (2.32.3)
# Requirement already satisfied: PyYAML>=5.3 in /opt/homebrew/anaconda3/envs/langchain_part_1/lib/python3.12/site-packages (from langchain_community) (6.0.2)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in /opt/homebrew/anaconda3/envs/langchain_part_1/lib/python3.12/site-packages (from langchain_community) (3.11.18)
# Requirement already satisfied: tenacity!=8.4.0,<10,>=8.1.0 in /opt/homebrew/anaconda3/envs/langchain_part_1/lib/python3.12/site-packages (from langchain_community) (9.1.2)
# Requirement already satisfied: dataclasses-json<0.7,>=0.5.7 in /opt/homebrew/anaconda3/envs/langchain_part_1/lib/python3.12/site-packages (from langchain_community) (0.6.7)
# Requirement already satisfied: pydantic-settings<3.0.0,>=2.4.0 in /opt/homebrew/anaconda3/envs/langchain_part_1/lib/python3.12/site-packages (from langchain_community) (2.9.1)
# Requirement already satisfied: langsmith<0.4,>=0.1.125 in /opt/homebrew/anaconda3/envs/langchain_part_1/lib/python3.12/site-packages (from langchain_community) (0.3.42)
# Requirement already satisfied: httpx-sse<1.0.0,>=0.4.0 in /opt/homebrew/anaconda3/envs/langchain_part_1/lib/python3.12/site-packages (from langchain_community) (0.4.0)
# Requirement already satisfied: numpy>=1.26.2 in /opt/homebrew/anaconda3/envs/langchain_part_1/lib/python3.12/site-packages (from langchain_community) (2.2.6)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /opt/homebrew/anaconda3/envs/langchain_part_1/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (2.6.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /opt/homebrew/anaconda3/envs/langchain_part_1/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (1.3.2)
# Requirement already satisfied: attrs>=17.3.0 in /opt/homebrew/anaconda3/envs/langchain_part_1/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (25.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /opt/homebrew/anaconda3/envs/langchain_part_1/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (1.6.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /opt/homebrew/anaconda3/envs/langchain_part_1/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (6.4.4)
# Requirement already satisfied: propcache>=0.2.0 in /opt/homebrew/anaconda3/envs/langchain_part_1/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (0.3.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /opt/homebrew/anaconda3/envs/langchain_part_1/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (1.20.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in /opt/homebrew/anaconda3/envs/langchain_part_1/lib/python3.12/site-packages (from dataclasses-json<0.7,>=0.5.7->langchain_community) (3.26.1)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in /opt/homebrew/anaconda3/envs/langchain_part_1/lib/python3.12/site-packages (from dataclasses-json<0.7,>=0.5.7->langchain_community) (0.9.0)
# Requirement already satisfied: langchain-text-splitters<1.0.0,>=0.3.8 in /opt/homebrew/anaconda3/envs/langchain_part_1/lib/python3.12/site-packages (from langchain<1.0.0,>=0.3.25->langchain_community) (0.3.8)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in /opt/homebrew/anaconda3/envs/langchain_part_1/lib/python3.12/site-packages (from langchain<1.0.0,>=0.3.25->langchain_community) (2.11.5)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in /opt/homebrew/anaconda3/envs/langchain_part_1/lib/python3.12/site-packages (from langchain-core<1.0.0,>=0.3.59->langchain_community) (1.33)
# Requirement already satisfied: packaging<25,>=23.2 in /opt/homebrew/anaconda3/envs/langchain_part_1/lib/python3.12/site-packages (from langchain-core<1.0.0,>=0.3.59->langchain_community) (24.2)
# Requirement already satisfied: typing-extensions>=4.7 in /opt/homebrew/anaconda3/envs/langchain_part_1/lib/python3.12/site-packages (from langchain-core<1.0.0,>=0.3.59->langchain_community) (4.13.2)
# Requirement already satisfied: jsonpointer>=1.9 in /opt/homebrew/anaconda3/envs/langchain_part_1/lib/python3.12/site-packages (from jsonpatch<2.0,>=1.33->langchain-core<1.0.0,>=0.3.59->langchain_community) (3.0.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /opt/homebrew/anaconda3/envs/langchain_part_1/lib/python3.12/site-packages (from langsmith<0.4,>=0.1.125->langchain_community) (0.28.1)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in /opt/homebrew/anaconda3/envs/langchain_part_1/lib/python3.12/site-packages (from langsmith<0.4,>=0.1.125->langchain_community) (3.10.18)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in /opt/homebrew/anaconda3/envs/langchain_part_1/lib/python3.12/site-packages (from langsmith<0.4,>=0.1.125->langchain_community) (1.0.0)
# Requirement already satisfied: zstandard<0.24.0,>=0.23.0 in /opt/homebrew/anaconda3/envs/langchain_part_1/lib/python3.12/site-packages (from langsmith<0.4,>=0.1.125->langchain_community) (0.23.0)
# Requirement already satisfied: anyio in /opt/homebrew/anaconda3/envs/langchain_part_1/lib/python3.12/site-packages (from httpx<1,>=0.23.0->langsmith<0.4,>=0.1.125->langchain_community) (4.9.0)
# Requirement already satisfied: certifi in /opt/homebrew/anaconda3/envs/langchain_part_1/lib/python3.12/site-packages (from httpx<1,>=0.23.0->langsmith<0.4,>=0.1.125->langchain_community) (2025.4.26)
# Requirement already satisfied: httpcore==1.* in /opt/homebrew/anaconda3/envs/langchain_part_1/lib/python3.12/site-packages (from httpx<1,>=0.23.0->langsmith<0.4,>=0.1.125->langchain_community) (1.0.9)
# Requirement already satisfied: idna in /opt/homebrew/anaconda3/envs/langchain_part_1/lib/python3.12/site-packages (from httpx<1,>=0.23.0->langsmith<0.4,>=0.1.125->langchain_community) (3.10)
# Requirement already satisfied: h11>=0.16 in /opt/homebrew/anaconda3/envs/langchain_part_1/lib/python3.12/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<0.4,>=0.1.125->langchain_community) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /opt/homebrew/anaconda3/envs/langchain_part_1/lib/python3.12/site-packages (from pydantic<3.0.0,>=2.7.4->langchain<1.0.0,>=0.3.25->langchain_community) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /opt/homebrew/anaconda3/envs/langchain_part_1/lib/python3.12/site-packages (from pydantic<3.0.0,>=2.7.4->langchain<1.0.0,>=0.3.25->langchain_community) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /opt/homebrew/anaconda3/envs/langchain_part_1/lib/python3.12/site-packages (from pydantic<3.0.0,>=2.7.4->langchain<1.0.0,>=0.3.25->langchain_community) (0.4.1)
# Requirement already satisfied: python-dotenv>=0.21.0 in /opt/homebrew/anaconda3/envs/langchain_part_1/lib/python3.12/site-packages (from pydantic-settings<3.0.0,>=2.4.0->langchain_community) (1.1.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /opt/homebrew/anaconda3/envs/langchain_part_1/lib/python3.12/site-packages (from requests<3,>=2->langchain_community) (3.4.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/homebrew/anaconda3/envs/langchain_part_1/lib/python3.12/site-packages (from requests<3,>=2->langchain_community) (2.4.0)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /opt/homebrew/anaconda3/envs/langchain_part_1/lib/python3.12/site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7,>=0.5.7->langchain_community) (1.1.0)
# Requirement already satisfied: sniffio>=1.1 in /opt/homebrew/anaconda3/envs/langchain_part_1/lib/python3.12/site-packages (from anyio->httpx<1,>=0.23.0->langsmith<0.4,>=0.1.125->langchain_community) (1.3.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
from langchain_community.callbacks import get_openai_callback

with get_openai_callback() as cb:
    # 첫 번째 호출
    res1 = llm.invoke("서울의 오늘 날씨는 어떤지 알려줘.")  # 프롬프트 예시
    print("응답1:", res1.content[:30], "...")  # 응답 일부 출력 (길 경우 잘라내기)
    # 두 번째 호출
    res2 = llm.invoke("파이썬으로 리스트 만드는 방법 예시를 알려줘.")
    print("응답2:", res2.content[:30], "...")

# 콜백 cb에는 블록 내 전체 토큰 사용량이 누적되어 있습니다.
print(f"총 토큰 수: {cb.total_tokens}")
print(f"프롬프트 토큰: {cb.prompt_tokens}")
print(f"응답 토큰: {cb.completion_tokens}")
print(f"총 비용 (USD): ${cb.total_cost:.6f}")
# Out:
# 응답1: 죄송하지만, 현재 실시간 날씨 정보를 제공할 수 없습니 ...
# 응답2: 파이썬에서 리스트를 만드는 방법에는 여러 가지가 있습니 ...
# 총 토큰 수: 467
# 프롬프트 토큰: 39
# 응답 토큰: 428
# 총 비용 (USD): $0.000175

# %%
from langchain_core.caches import InMemoryCache
from langchain_core.globals import set_llm_cache
import time


#비활성화시킴
# set_llm_cache(None) 
# InMemoryCache 설정
set_llm_cache(InMemoryCache())

# %%
query = "rag의 특징을 알려줘"  # 동일한 질문을 두 번 보낼 예정
# 첫 번째 호출 (캐시에 없다면 API 호출 발생)
start = time.time()
result1 = llm.invoke(query)
end = time.time()
print("응답1:", result1.content)
print(f'{end-start:.3f}')

# 두 번째 호출 (동일한 query, 캐시 히트 시 API 미호출)
start = time.time()
result2 = llm.invoke(query)
end = time.time()
print("응답2:", result2.content)
print(f'{end-start:.3f}')
# Out:
# 응답1: RAG( Retrieval-Augmented Generation)는 자연어 처리 분야에서 사용되는 모델로, 기존의 생성 모델과 정보 검색(리트리벌) 기술을 결합한 방식입니다. RAG의 주요 특징은 다음과 같습니다:
#
# 1. **외부 지식 활용**: RAG는 사전 학습된 언어 모델에 더해, 외부 데이터베이스나 문서 집합에서 관련 정보를 검색하여 답변에 반영합니다. 이를 통해 최신 정보나 방대한 지식을 효과적으로 활용할 수 있습니다.
#
# 2. **생성과 검색의 결합**: 단순히 텍스트를 생성하는 것뿐만 아니라, 관련 문서를 검색하여 그 내용을 바탕으로 답변을 생성하므로, 더 정확하고 풍부한 정보를 제공할 수 있습니다.
#
# 3. **유연성**: 다양한 도메인이나 주제에 대해 적응이 가능하며, 특정 분야의 지식을 빠르게 업데이트하거나 확장하는 데 유리합니다.
#
# 4. **개선된 성능**: 검색 기반의 보조를 통해, 기존의 생성 모델보다 사실성(factuality)이 높고, 정보의 신뢰성을 향상시킬 수 있습니다.
#
# 5. **적용 분야**: 질문 답변 시스템, 대화형 에이전트, 문서 요약, 정보 검색 등 다양한 자연어 처리 작업에 활용됩니다.
#
# 요약하자면, RAG는 검색과 생성의 강점을 결합하여, 더 정확하고 풍부한 자연어 처리 결과를 제공하는 모델입니다.
# 3.250
# 응답2: RAG( Retrieval-Augmented Generation)는 자연어 처리 분야에서 사용되는 모델로, 기존의 생성 모델과 정보 검색(리트리벌) 기술을 결합한 방식입니다. RAG의 주요 특징은 다음과 같습니다:
#
# 1. **외부 지식 활용**: RAG는 사전 학습된 언어 모델에 더해, 외부 데이터베이스나 문서 집합에서 관련 정보를 검색하여 답변에 반영합니다. 이를 통해 최신 정보나 방대한 지식을 효과적으로 활용할 수 있습니다.
#
# 2. **생성과 검색의 결합**: 단순히 텍스트를 생성하는 것뿐만 아니라, 관련 문서를 검색하여 그 내용을 바탕으로 답변을 생성하므로, 더 정확하고 풍부한 정보를 제공할 수 있습니다.
#
# 3. **유연성**: 다양한 도메인이나 주제에 대해 적응이 가능하며, 특정 분야의 지식을 빠르게 업데이트하거나 확장하는 데 유리합니다.
#
# 4. **개선된 성능**: 검색 기반의 보조를 통해, 기존의 생성 모델보다 사실성(factuality)이 높고, 정보의 신뢰성을 향상시킬 수 있습니다.
#
# 5. **적용 분야**: 질문 답변 시스템, 대화형 에이전트, 문서 요약, 정보 검색 등 다양한 자연어 처리 작업에 활용됩니다.
#
# 요약하자면, RAG는 검색과 생성의 강점을 결합하여, 더 정확하고 풍부한 자연어 처리 결과를 제공하는 모델입니다.
# 0.001

# %%
result2.usage_metadata
# Out:
# {'input_tokens': 13,
#  'output_tokens': 324,
#  'total_tokens': 337,
#  'input_token_details': {'audio': 0, 'cache_read': 0},
#  'output_token_details': {'audio': 0, 'reasoning': 0}}

# %%
from langchain.prompts import PromptTemplate

# 1. 템플릿 문자열 정의 (한국어로 작성)
template_str = (
    "당신은 최고 수준의 마케팅 카피라이터입니다.\n"
    "아래 제품의 매력적인 홍보 문구를 100자 내외로 작성해주세요.\n\n"
    "제품명: {product_name}\n"
    "출시년도: {prod_year}"
)

# 2. PromptTemplate 객체 생성
product_prompt = PromptTemplate.from_template(template_str)

# 3. 템플릿에 값 채워보기 (format)
formatted_prompt = product_prompt.format(product_name="슈퍼카메라 X100",prod_year=2025)
print(formatted_prompt)
# Out:
# 당신은 최고 수준의 마케팅 카피라이터입니다.
# 아래 제품의 매력적인 홍보 문구를 100자 내외로 작성해주세요.
#
# 제품명: 슈퍼카메라 X100
# 출시년도: 2025

# %%
from langchain_openai import ChatOpenAI

# OpenAI GPT-4o-mini 모델 초기화 (temperature=0으로 설정하여 출력 안정성 강화)
llm = ChatOpenAI(model="gpt-4o-mini", temperature=0)

# RunnableSequence 객체 생성 (파이프라인 형태)
chain = product_prompt | llm

# invoke 메서드를 사용하여 명시적으로 호출
result = chain.invoke({"product_name": "슈퍼카메라 X100","prod_year":2025})
print(result)
# Out:
# content='2025년 출시된 슈퍼카메라 X100으로 순간을 선명하게 포착하세요. 혁신적인 성능과 세련된 디자인이 만나는 최고의 선택!' additional_kwargs={'refusal': None} response_metadata={'token_usage': {'completion_tokens': 39, 'prompt_tokens': 61, 'total_tokens': 100, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-mini-2025-04-14', 'system_fingerprint': 'fp_eede8f0d45', 'id': 'chatcmpl-BadksAwbqJqYNq9G3UBbUDGf8BtnM', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None} id='run--6f203c62-e5c6-4a97-848d-a8480d366517-0' usage_metadata={'input_tokens': 61, 'output_tokens': 39, 'total_tokens': 100, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}

# %%
result.content
# Out:
# '2025년 출시된 슈퍼카메라 X100으로 순간을 선명하게 포착하세요. 혁신적인 성능과 세련된 디자인이 만나는 최고의 선택!'

# %%
# 1. 다중 입력 템플릿 문자열 정의
multi_template_str = (
    "아래는 뉴스 기사 제목과 키워드입니다.\n"
    "이 정보를 바탕으로 한 문단으로 구성된 간략한 요약문을 작성하세요.\n\n"
    "제목: {title}\n"
    "키워드: {keywords}"
)

# 2. PromptTemplate 객체 생성 (두 개의 input_variables 지정)
summary_prompt = PromptTemplate(
    template=multi_template_str, input_variables=["title", "keywords"]
)

# 3. 예시 값으로 포맷팅하여 프롬프트 확인
sample_title = "인공지능 기술의 발전과 미래"
sample_keywords = "머신러닝, 딥러닝, 산업 혁신"
formatted_summary_prompt = summary_prompt.format(title=sample_title, keywords=sample_keywords)
print(formatted_summary_prompt)
# Out:
# 아래는 뉴스 기사 제목과 키워드입니다.
# 이 정보를 바탕으로 한 문단으로 구성된 간략한 요약문을 작성하세요.
#
# 제목: 인공지능 기술의 발전과 미래
# 키워드: 머신러닝, 딥러닝, 산업 혁신

# %%
# 4. 프롬프트 템플릿과 LLM 실행 (파이프라인 사용)
result_summary = (summary_prompt | llm).invoke({
    "title": sample_title,
    "keywords": sample_keywords
})
print(result_summary)
# Out:
# content='인공지능 기술은 머신러닝과 딥러닝의 발전을 바탕으로 빠르게 진화하며 산업 전반에 혁신을 일으키고 있습니다. 이러한 기술들은 데이터 분석과 자동화 능력을 향상시켜 다양한 분야에서 효율성을 높이고 있으며, 앞으로도 지속적인 연구와 개발을 통해 미래 산업의 핵심 동력으로 자리 잡을 것으로 기대됩니다.' additional_kwargs={'refusal': None} response_metadata={'token_usage': {'completion_tokens': 85, 'prompt_tokens': 68, 'total_tokens': 153, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-mini-2025-04-14', 'system_fingerprint': 'fp_17d1f82c3e', 'id': 'chatcmpl-BadktcwjMibU8Yk33extKXshSccxK', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None} id='run--6e87be45-cb72-45a0-bdb9-c275a2fc996b-0' usage_metadata={'input_tokens': 68, 'output_tokens': 85, 'total_tokens': 153, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}

# %%
# 1. 템플릿 문자열 정의 (한국어로 작성)
template_str = (
    "당신은 최고 수준의 마케팅 카피라이터입니다.\n"
    "아래 제품의 매력적인 홍보 문구를 100자 내외로 작성해주세요.\n\n"
    "제품명: {product_name}\n"
    "출시년도: {prod_year}"
)

# 2. PromptTemplate 객체 생성
product_prompt = PromptTemplate(template=template_str,
                                input_variables=["product_name", "prod_year"])

# 3. 템플릿에 값 채워보기 (format)
product_name="슈퍼카메라 X100"
prod_year="2025"
formatted_prompt = product_prompt.format(product_name=product_name,prod_year=prod_year)
print(formatted_prompt)
# Out:
# 당신은 최고 수준의 마케팅 카피라이터입니다.
# 아래 제품의 매력적인 홍보 문구를 100자 내외로 작성해주세요.
#
# 제품명: 슈퍼카메라 X100
# 출시년도: 2025

# %%
# 4. 프롬프트 템플릿과 LLM 실행 (파이프라인 사용)
result_summary = (product_prompt | llm).invoke({
    "product_name": product_name,
    "prod_year": prod_year
})
print(result_summary.content)
# Out:
# 2025년 출시된 슈퍼카메라 X100으로 순간을 선명하게 포착하세요. 혁신적인 성능과 세련된 디자인이 만나는 최고의 선택!

# %%
from langchain.prompts import ChatPromptTemplate

# 1. 시스템 및 사용자 템플릿 정의
system_message = ("당신은 Python 분야의 뛰어난 전문가이자 조언자입니다. "
                  "사용자의 프로그래밍 질문에 대해 친절하고 이해하기 쉽게 답변해주세요.")
user_message = "{question}"  # 사용자 질문은 실행 시 채워질 변수

# 2. ChatPromptTemplate.from_messages를 사용하여 역할별 프롬프트 템플릿 생성
chat_prompt = ChatPromptTemplate.from_messages([
    ("system", system_message),
    ("user", user_message)
])
# 3. format_messages로 예시 질문을 채워 메시지 목록 생성
sample_question = "파이썬의 리스트 컴프리헨션(list comprehension)과 map 함수의 차이가 무엇인가요?"
messages = chat_prompt.format_messages(question=sample_question)
print(messages)
# Out:
# [SystemMessage(content='당신은 Python 분야의 뛰어난 전문가이자 조언자입니다. 사용자의 프로그래밍 질문에 대해 친절하고 이해하기 쉽게 답변해주세요.', additional_kwargs={}, response_metadata={}), HumanMessage(content='파이썬의 리스트 컴프리헨션(list comprehension)과 map 함수의 차이가 무엇인가요?', additional_kwargs={}, response_metadata={})]

# %%
from langchain.prompts import ChatPromptTemplate

chat_prompt = ChatPromptTemplate.from_messages([
    ("system", ("당신은 Python 분야의 뛰어난 전문가이자 조언자입니다. "
                  "사용자의 프로그래밍 질문에 대해 친절하고 이해하기 쉽게 답변해주세요.")),
    ("user", "{question}" )
])
chain = chat_prompt | llm
answer = chain.invoke({"question":"파이썬의 리스트 내포에 대해 설명해줘"})
print(answer.content)
# Out:
# 물론입니다! 파이썬의 리스트 내포(List Comprehension)는 기존 리스트를 기반으로 새 리스트를 간결하고 효율적으로 만드는 방법입니다. 반복문과 조건문을 한 줄로 표현할 수 있어서 코드가 더 깔끔해지고 읽기 쉬워집니다.
#
# ### 기본 구조
# ```python
# 새로운 리스트 = [표현식 for 항목 in 기존 리스트]
# ```
#
# ### 예제 1: 1부터 10까지의 제곱수 리스트 만들기
# ```python
# squares = [x**2 for x in range(1, 11)]
# print(squares)
# # 출력: [1, 4, 9, 16, 25, 36, 49, 64, 81, 100]
# ```
#
# ### 예제 2: 조건문을 포함한 리스트 내포
# 짝수만 선택해서 리스트 만들기
# ```python
# evens = [x for x in range(1, 11) if x % 2 == 0]
# print(evens)
# # 출력: [2, 4, 6, 8, 10]
# ```
#
# ### 예제 3: 중첩 리스트 내포
# 2차원 리스트를 1차원으로 평탄화하기
# ```python
# matrix = [[1, 2], [3, 4], [5, 6]]
# flattened = [num for row in matrix for num in row]
# print(flattened)
# # 출력: [1, 2, 3, 4, 5, 6]
# ```
#
# ### 요약
# - 리스트 내포는 기존 리스트를 기반으로 새 리스트를 빠르게 만들 때 유용합니다.
# - 반복문(`for`)과 조건문(`if`)을 한 줄로 표현할 수 있어 코드가 간결해집니다.
# - 복잡한 로직도 적절히 활용하면 가독성을 높일 수 있습니다.
#
# 궁금한 점이 있거나 더 구체적인 예제가 필요하시면 언제든 말씀해 주세요!

# %%
from langchain.prompts import SystemMessagePromptTemplate, HumanMessagePromptTemplate

# 1. 시스템/사용자용 BaseMessagePromptTemplate 생성
role_system_template = "당신은 {role} 분야의 전문 지식인입니다. 가능한 한 자세히 답변해 주세요."
system_prompt = SystemMessagePromptTemplate.from_template(role_system_template)
user_prompt = HumanMessagePromptTemplate.from_template("{question}")

# 2. ChatPromptTemplate 생성 (role과 question 변수를 사용)
base_chat_prompt = ChatPromptTemplate.from_messages([system_prompt, user_prompt])

# 3. PartialPromptTemplate: role 변수를 미리 채워 새로운 프롬프트 생성
partial_chat_prompt = base_chat_prompt.partial(role="주식 투자")

# %%
# 4. partial로 생성된 프롬프트에 질문만 채워 프롬프트 구성
sample_question = "현재 2025년 3월 시장 상황에서 삼성전자 주식 전망은 어떻습니까?"
messages = partial_chat_prompt.format_messages(question=sample_question)
print(messages)
# Out:
# [SystemMessage(content='당신은 주식 투자 분야의 전문 지식인입니다. 가능한 한 자세히 답변해 주세요.', additional_kwargs={}, response_metadata={}), HumanMessage(content='현재 2025년 3월 시장 상황에서 삼성전자 주식 전망은 어떻습니까?', additional_kwargs={}, response_metadata={})]

# %%
chain = partial_chat_prompt | llm
answer = chain.invoke({"question":sample_question})
print(answer.content)
# Out:
# 2025년 3월 현재 시장 상황을 고려할 때, 삼성전자 주식의 전망은 여러 요인에 따라 달라질 수 있습니다. 아래에 주요 분석 포인트와 전망을 상세히 설명드리겠습니다.
#
# 1. 글로벌 반도체 및 IT 시장 동향
# - 반도체 수요 회복: 2024년 이후 글로벌 반도체 시장은 인공지능(AI), 5G, 자율주행차, 클라우드 컴퓨팅 등 신기술 수요 증가로 인해 회복세를 보이고 있습니다. 삼성전자는 세계 최대 반도체 제조업체 중 하나로, 이 수요 증가의 수혜를 받을 가능성이 높습니다.
# - 공급망 안정화: 공급망 문제는 일부 기간 동안 주가 변동성을 야기했으나, 2024년 이후 공급망이 점차 안정화되면서 생산 능력 확대와 비용 절감이 기대됩니다.
#
# 2. 스마트폰 및 소비자 가전 시장
# - 프리미엄 스마트폰 시장: 갤럭시 시리즈의 경쟁력 유지와 신기술 도입(예: 폴더블 디스플레이, 5G/6G 통신 기술)이 지속되면 매출이 견조할 것으로 예상됩니다.
# - 신제품 출시 및 혁신: 2024년 하반기와 2025년 초에 예정된 신제품 출시는 주가에 긍정적 영향을 미칠 수 있습니다.
#
# 3. 기술 혁신 및 신사업
# - 인공지능, 퀀텀닷, 배터리 등 신기술 개발에 대한 투자 확대는 삼성전자의 미래 성장 동력을 강화할 수 있습니다.
# - 친환경 및 지속가능성 전략: 친환경 소재 및 에너지 효율 향상 등 ESG(환경·사회·지배구조) 전략이 기업 이미지와 투자자 신뢰를 높이고 있습니다.
#
# 4. 글로벌 경제 및 정책 환경
# - 미국, 중국, 유럽 등 주요 시장의 경제 정책, 무역 정책, 환율 변동이 삼성전자 실적에 영향을 미칠 수 있습니다.
# - 반도체 및 IT 산업에 대한 정부 정책, 보조금, 규제 변화도 중요한 변수입니다.
#
# 5. 재무 상태 및 주가 평가
# - 삼성전자는 안정적인 재무구조와 높은 현금 유동성을 유지하고 있어, 시장 변동성에 대한 방어력이 강합니다.
# - PER(주가수익비율), PBR(주가순자산비율) 등 지표를 고려할 때, 현재 주가가 과대평가 또는 저평가된 상태인지 분석이 필요합니다.
#
# **전망 요약:**
#
# - **긍정적 요인:** 글로벌 반도체 수요 증가, 신기술 도입, 신제품 출시, 안정적인 재무구조
# - **우려 요인:** 글로벌 경기 둔화 가능성, 미중 무역 긴장, 환율 변동성, 경쟁 심화
#
# **결론:**
# 2025년 3월 현재, 삼성전자는 반도체와 IT 산업의 성장세를 바탕으로 장기적 성장 잠재력을 갖추고 있으며, 단기적으로는 글로벌 경제 상황과 정책 변수에 따라 변동성이 존재합니다. 투자 시에는 이러한 요인들을 종합적으로 고려하여 분산 투자와 리스크 관리 전략을 세우는 것이 바람직합니다.
#
# 추가로, 최신 시장 데이터와 기업 실적 발표, 기술 개발 동향 등을 지속적으로 모니터링하는 것이 중요합니다. 투자 결정 전에 전문가의 상세 분석과 재무 상담을 받는 것도 권장드립니다.

# %%
from langchain.prompts import PromptTemplate
from langchain_core.output_parsers import StrOutputParser

# 출력 파서와 프롬프트 설정
prompt = PromptTemplate(
    template="질문: {question}\n한 단어로 답하세요.", 
    input_variables=["question"]
)

# 체인 구성: PromptTemplate | LLM | OutputParser
chain = prompt | llm | StrOutputParser()

# 테스트 실행 (.invoke)
query = {"question": "서울은 어느 나라의 수도인가?"}
result = chain.invoke(query)

print("원본 문자열 출력:", result)
print("출력 타입:", type(result))
print("응답 글자수:", len(result))
# Out:
# 원본 문자열 출력: 한국
# 출력 타입: <class 'str'>
# 응답 글자수: 2

# %%
from langchain_core.output_parsers import JsonOutputParser

json_parser = JsonOutputParser()

# 프롬프트 템플릿 정의
movie_prompt = PromptTemplate(
    template=(
        "다음 사용자 취향에 맞는 영화를 한 편 추천해주세요.\n"
        "취향: {preference}\n\n"
        "아래 형식의 JSON으로만 답변하세요 (추가 설명 금지):\n"
        '{{ "title": "<영화 제목>", "year": <출시년도>, "genre": "<장르>" }}'
    ),
    input_variables=["preference"]
)

chain = movie_prompt | llm | json_parser

# 입력 예: SF 장르를 좋아하는 경우
user_input = {"preference": "SF (공상 과학)"}
result_dict = chain.invoke(user_input)

print("출력 타입:", type(result_dict))
print("JSON 파싱 결과:\n", result_dict)
print("제목:", result_dict.get("title"))
# Out:
# 출력 타입: <class 'dict'>
# JSON 파싱 결과:
#  {'title': '인터스텔라', 'year': 2014, 'genre': 'SF'}
# 제목: 인터스텔라

# %%
# 파서 포맷 지시어
from langchain_core.output_parsers import JsonOutputParser,CommaSeparatedListOutputParser

parser1 = JsonOutputParser()
parser2 = CommaSeparatedListOutputParser()
print(parser1.get_format_instructions())
print(parser2.get_format_instructions())
# Out:
# Return a JSON object.
# Your response should be a list of comma separated values, eg: `foo, bar, baz` or `foo,bar,baz`

# %%
# %pip install langchain-redis redis
# Out:
# Requirement already satisfied: langchain-redis in /opt/homebrew/anaconda3/envs/langchain_part_1/lib/python3.12/site-packages (0.2.1)
# Requirement already satisfied: redis in /opt/homebrew/anaconda3/envs/langchain_part_1/lib/python3.12/site-packages (5.3.0)
# Requirement already satisfied: anyio<5.0.0,>=4.9.0 in /opt/homebrew/anaconda3/envs/langchain_part_1/lib/python3.12/site-packages (from langchain-redis) (4.9.0)
# Requirement already satisfied: certifi<2026.0.0,>=2025.4.26 in /opt/homebrew/anaconda3/envs/langchain_part_1/lib/python3.12/site-packages (from langchain-redis) (2025.4.26)
# Requirement already satisfied: httpcore<2.0.0,>=1.0.9 in /opt/homebrew/anaconda3/envs/langchain_part_1/lib/python3.12/site-packages (from langchain-redis) (1.0.9)
# Requirement already satisfied: jinja2<4.0.0,>=3.1.6 in /opt/homebrew/anaconda3/envs/langchain_part_1/lib/python3.12/site-packages (from langchain-redis) (3.1.6)
# Requirement already satisfied: langchain-core<0.4,>=0.3 in /opt/homebrew/anaconda3/envs/langchain_part_1/lib/python3.12/site-packages (from langchain-redis) (0.3.61)
# Requirement already satisfied: numpy<3,>=2 in /opt/homebrew/anaconda3/envs/langchain_part_1/lib/python3.12/site-packages (from langchain-redis) (2.2.6)
# Requirement already satisfied: python-ulid<4,>=3 in /opt/homebrew/anaconda3/envs/langchain_part_1/lib/python3.12/site-packages (from langchain-redis) (3.0.0)
# Requirement already satisfied: redisvl<0.7.0,>=0.6.0 in /opt/homebrew/anaconda3/envs/langchain_part_1/lib/python3.12/site-packages (from langchain-redis) (0.6.0)
# Requirement already satisfied: tenacity<10.0.0,>=9.1.2 in /opt/homebrew/anaconda3/envs/langchain_part_1/lib/python3.12/site-packages (from langchain-redis) (9.1.2)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.13.2 in /opt/homebrew/anaconda3/envs/langchain_part_1/lib/python3.12/site-packages (from langchain-redis) (4.13.2)
# Requirement already satisfied: urllib3<3.0.0,>=2.4.0 in /opt/homebrew/anaconda3/envs/langchain_part_1/lib/python3.12/site-packages (from langchain-redis) (2.4.0)
# Requirement already satisfied: idna>=2.8 in /opt/homebrew/anaconda3/envs/langchain_part_1/lib/python3.12/site-packages (from anyio<5.0.0,>=4.9.0->langchain-redis) (3.10)
# Requirement already satisfied: sniffio>=1.1 in /opt/homebrew/anaconda3/envs/langchain_part_1/lib/python3.12/site-packages (from anyio<5.0.0,>=4.9.0->langchain-redis) (1.3.1)
# Requirement already satisfied: h11>=0.16 in /opt/homebrew/anaconda3/envs/langchain_part_1/lib/python3.12/site-packages (from httpcore<2.0.0,>=1.0.9->langchain-redis) (0.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/homebrew/anaconda3/envs/langchain_part_1/lib/python3.12/site-packages (from jinja2<4.0.0,>=3.1.6->langchain-redis) (3.0.2)
# Requirement already satisfied: langsmith<0.4,>=0.1.126 in /opt/homebrew/anaconda3/envs/langchain_part_1/lib/python3.12/site-packages (from langchain-core<0.4,>=0.3->langchain-redis) (0.3.42)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in /opt/homebrew/anaconda3/envs/langchain_part_1/lib/python3.12/site-packages (from langchain-core<0.4,>=0.3->langchain-redis) (1.33)
# Requirement already satisfied: PyYAML>=5.3 in /opt/homebrew/anaconda3/envs/langchain_part_1/lib/python3.12/site-packages (from langchain-core<0.4,>=0.3->langchain-redis) (6.0.2)
# Requirement already satisfied: packaging<25,>=23.2 in /opt/homebrew/anaconda3/envs/langchain_part_1/lib/python3.12/site-packages (from langchain-core<0.4,>=0.3->langchain-redis) (24.2)
# Requirement already satisfied: pydantic>=2.7.4 in /opt/homebrew/anaconda3/envs/langchain_part_1/lib/python3.12/site-packages (from langchain-core<0.4,>=0.3->langchain-redis) (2.11.5)
# Requirement already satisfied: jsonpointer>=1.9 in /opt/homebrew/anaconda3/envs/langchain_part_1/lib/python3.12/site-packages (from jsonpatch<2.0,>=1.33->langchain-core<0.4,>=0.3->langchain-redis) (3.0.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /opt/homebrew/anaconda3/envs/langchain_part_1/lib/python3.12/site-packages (from langsmith<0.4,>=0.1.126->langchain-core<0.4,>=0.3->langchain-redis) (0.28.1)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in /opt/homebrew/anaconda3/envs/langchain_part_1/lib/python3.12/site-packages (from langsmith<0.4,>=0.1.126->langchain-core<0.4,>=0.3->langchain-redis) (3.10.18)
# Requirement already satisfied: requests<3,>=2 in /opt/homebrew/anaconda3/envs/langchain_part_1/lib/python3.12/site-packages (from langsmith<0.4,>=0.1.126->langchain-core<0.4,>=0.3->langchain-redis) (2.32.3)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in /opt/homebrew/anaconda3/envs/langchain_part_1/lib/python3.12/site-packages (from langsmith<0.4,>=0.1.126->langchain-core<0.4,>=0.3->langchain-redis) (1.0.0)
# Requirement already satisfied: zstandard<0.24.0,>=0.23.0 in /opt/homebrew/anaconda3/envs/langchain_part_1/lib/python3.12/site-packages (from langsmith<0.4,>=0.1.126->langchain-core<0.4,>=0.3->langchain-redis) (0.23.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /opt/homebrew/anaconda3/envs/langchain_part_1/lib/python3.12/site-packages (from pydantic>=2.7.4->langchain-core<0.4,>=0.3->langchain-redis) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /opt/homebrew/anaconda3/envs/langchain_part_1/lib/python3.12/site-packages (from pydantic>=2.7.4->langchain-core<0.4,>=0.3->langchain-redis) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /opt/homebrew/anaconda3/envs/langchain_part_1/lib/python3.12/site-packages (from pydantic>=2.7.4->langchain-core<0.4,>=0.3->langchain-redis) (0.4.1)
# Requirement already satisfied: jsonpath-ng<2.0.0,>=1.5.0 in /opt/homebrew/anaconda3/envs/langchain_part_1/lib/python3.12/site-packages (from redisvl<0.7.0,>=0.6.0->langchain-redis) (1.7.0)
# Requirement already satisfied: ml-dtypes<1.0.0,>=0.4.0 in /opt/homebrew/anaconda3/envs/langchain_part_1/lib/python3.12/site-packages (from redisvl<0.7.0,>=0.6.0->langchain-redis) (0.5.1)
# Requirement already satisfied: PyJWT~=2.9.0 in /opt/homebrew/anaconda3/envs/langchain_part_1/lib/python3.12/site-packages (from redis) (2.9.0)
# Requirement already satisfied: ply in /opt/homebrew/anaconda3/envs/langchain_part_1/lib/python3.12/site-packages (from jsonpath-ng<2.0.0,>=1.5.0->redisvl<0.7.0,>=0.6.0->langchain-redis) (3.11)
# Requirement already satisfied: charset_normalizer<4,>=2 in /opt/homebrew/anaconda3/envs/langchain_part_1/lib/python3.12/site-packages (from requests<3,>=2->langsmith<0.4,>=0.1.126->langchain-core<0.4,>=0.3->langchain-redis) (3.4.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
import os
load_dotenv()
REDIS_URL = os.getenv("REDIS_URL")
print(REDIS_URL)
# Out:
# redis://default:8Koj75mY4FTX6ni7pCr66TMZick30p0r@redis-15886.c89.us-east-1-3.ec2.redns.redis-cloud.com:15886

# %%
from langchain_redis import RedisChatMessageHistory

session_id = "user_123"

# 세션별 Redis 기반 채팅 기록 가져오기/생성
history = RedisChatMessageHistory(session_id=session_id, redis_url=REDIS_URL)
history.add_user_message("Redis에 이 대화 기록을 저장하고 있나요?")
history.add_ai_message("네, 이 대화는 Redis에 저장됩니다. 세션이 유지되는 한 기록을 복원할 수 있어요.")

print(f"현재 Redis에 저장된 '{session_id}' 대화 수: {len(history.messages)}")
# Out:
# 현재 Redis에 저장된 'user_123' 대화 수: 6

# %%
from langchain_core.prompts import ChatPromptTemplate,MessagesPlaceholder

prompt = ChatPromptTemplate.from_messages([
  ('system','당신은 친절한 상담봇입니다.'),
  MessagesPlaceholder(variable_name='history'),
  ('user','{question}')
])

chain = prompt | llm | StrOutputParser()

# %%
from langchain_core.chat_history import InMemoryChatMessageHistory
from  langchain_core.runnables.history import RunnableWithMessageHistory
store = {} # 세션별 대화내역 저장소
def get_session_history(session_id):
  if session_id not in store:
    store[session_id] = InMemoryChatMessageHistory()
  return store[session_id]

chatbot = RunnableWithMessageHistory(
  chain,
  get_session_history,
  input_messages_key='question',
  history_messages_key='history'
)

# %%
answer = chatbot.invoke({'question':'사과 10개를 사고 2개를 먹었다면 몇 개가 남았을까?'},
                config={'configurable':{'session_id':'user_1'}})
print(answer)

answer = chatbot.invoke({'question':'안녕하세요. 저는 홍길동입니다.'},
                config={'configurable':{'session_id':'user_2'}})
print(answer)

answer = chatbot.invoke({'question':'남은 사과에서 1개를 더 먹으면 몇 개가 남았을까?'},
                config={'configurable':{'session_id':'user_1'}})
print(answer)

answer = chatbot.invoke({'question':'제 이름이 뭐라고요?'},
                config={'configurable':{'session_id':'user_2'}})
print(answer)
# Out:
# 16:39:06 httpx INFO   HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 사과 10개를 사고 2개를 먹었다면, 남은 사과는 8개입니다.
# 16:39:07 httpx INFO   HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 안녕하세요, 홍길동님! 어떻게 도와드릴까요?
# 16:39:08 httpx INFO   HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 남은 사과가 8개에서 1개를 더 먹으면, 남은 사과는 7개가 됩니다.
# 16:39:09 httpx INFO   HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 홍길동님이라고 하셨습니다. 맞나요? 더 궁금한 점이나 도와드릴 일이 있으시면 말씀해 주세요!

# %%
answer = chatbot.invoke({'question':'최종 남는 사과는 몇개인가요?'},
                config={'configurable':{'session_id':'user_2'}})
print(answer)
# Out:
# 16:39:10 httpx INFO   HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 최종 남는 사과의 개수에 대해 알려면, 사과를 어떻게 나누거나 먹는지에 대한 구체적인 상황이나 조건이 필요합니다. 예를 들어, 사과를 몇 명이 나누어 먹거나, 어떤 규칙으로 사과를 먹거나 남기는지 알려주시면 더 정확히 답변드릴 수 있습니다. 자세한 상황을 말씀해 주시겠어요?

# %%
get_session_history('user_1')
# Out:
# InMemoryChatMessageHistory(messages=[HumanMessage(content='사과 10개를 사고 2개를 먹었다면 몇 개가 남았을까?', additional_kwargs={}, response_metadata={}), AIMessage(content='사과 10개를 사고 2개를 먹었다면, 남은 사과는 8개입니다.', additional_kwargs={}, response_metadata={}), HumanMessage(content='남은 사과에서 1개를 더 먹으면 몇 개가 남았을까?', additional_kwargs={}, response_metadata={}), AIMessage(content='남은 사과가 8개에서 1개를 더 먹으면, 남은 사과는 7개가 됩니다.', additional_kwargs={}, response_metadata={})])

# %%
get_session_history('user_2')
# Out:
# InMemoryChatMessageHistory(messages=[HumanMessage(content='안녕하세요. 저는 홍길동입니다.', additional_kwargs={}, response_metadata={}), AIMessage(content='안녕하세요, 홍길동님! 어떻게 도와드릴까요?', additional_kwargs={}, response_metadata={}), HumanMessage(content='제 이름이 뭐라고요?', additional_kwargs={}, response_metadata={}), AIMessage(content='홍길동님이라고 하셨습니다. 맞나요? 더 궁금한 점이나 도와드릴 일이 있으시면 말씀해 주세요!', additional_kwargs={}, response_metadata={}), HumanMessage(content='최종 남는 사과는 몇개인가요?', additional_kwargs={}, response_metadata={}), AIMessage(content='최종 남는 사과의 개수에 대해 알려면, 사과를 어떻게 나누거나 먹는지에 대한 구체적인 상황이나 조건이 필요합니다. 예를 들어, 사과를 몇 명이 나누어 먹거나, 어떤 규칙으로 사과를 먹거나 남기는지 알려주시면 더 정확히 답변드릴 수 있습니다. 자세한 상황을 말씀해 주시겠어요?', additional_kwargs={}, response_metadata={})])

# %%
# 요약용 프롬프트 템플릿 (대화 내용을 한국어로 요약)
summary_prompt = ChatPromptTemplate.from_messages([
    ("system", "당신은 대화 요약 도우미입니다. 대화의 주요 내용을 간결하게 요약하세요."),
    ("human", "{conversation}")  # 전체 대화 내용을 하나의 문자열로 제공
])
summary_chain = summary_prompt | llm | StrOutputParser()

# %%
from langchain_core.messages import HumanMessage, AIMessage


session = 'user_c'  # 세션 ID
# user_c 세션의 대화 기록 가져오기
history = get_session_history(session)


# 기존 대화 내용을 수동으로 저장
history.add_user_message("안녕, 오늘 우리는 무엇을 할 예정이었지?")
history.add_ai_message("안녕하세요! 오늘은 내일 진행할 회의 자료를 준비하기로 예정되어 있었어요. 미리 관련 자료들을 점검하고 최종 내용을 정리할 계획입니다.")


history.add_user_message("아, 맞다. 내일 회의 자료 준비해야 했지. 회의는 몇 시였어?")
history.add_ai_message("내일 회의는 오전 10시에 시작할 예정이에요. 자료 준비는 그 전까지 완료하면 좋겠습니다.")


history.add_user_message("그 회의에 누가 참석하는지도 기억나?")
history.add_ai_message("네, 내일 회의에는 김 팀장님과 이 과장님, 그리고 프로젝트 X 담당자인 최 대리님이 참석할 예정입니다.")


history.add_user_message("프로젝트 X의 진행 상황도 공유해야 하나?")
history.add_ai_message("맞습니다. 프로젝트 X의 최근 진행 상황과 주요 이슈에 대해 간략히 공유하고 논의할 예정이에요. 진행 상황을 미리 정리해 두는 게 좋겠습니다.")


history.add_user_message("최근에 이야기 나눴던 새로운 디자인에 대한 업데이트는 있어?")
history.add_ai_message("네, 최근 새로운 디자인 시안이 나왔습니다. 주요 변경 사항으로는 컬러 팔레트가 좀 더 현대적인 톤으로 바뀌었고, UI 레이아웃도 보다 직관적으로 수정되었어요. 이번 회의에서 간략히 소개할 예정입니다.")


print(f"요약 전 user_c 메모리 메시지 개수: {len(store[session].messages)}")
print(store[session])  # 요약 전 대화 내용 출력
# Out:
# 요약 전 user_c 메모리 메시지 개수: 10
# Human: 안녕, 오늘 우리는 무엇을 할 예정이었지?
# AI: 안녕하세요! 오늘은 내일 진행할 회의 자료를 준비하기로 예정되어 있었어요. 미리 관련 자료들을 점검하고 최종 내용을 정리할 계획입니다.
# Human: 아, 맞다. 내일 회의 자료 준비해야 했지. 회의는 몇 시였어?
# AI: 내일 회의는 오전 10시에 시작할 예정이에요. 자료 준비는 그 전까지 완료하면 좋겠습니다.
# Human: 그 회의에 누가 참석하는지도 기억나?
# AI: 네, 내일 회의에는 김 팀장님과 이 과장님, 그리고 프로젝트 X 담당자인 최 대리님이 참석할 예정입니다.
# Human: 프로젝트 X의 진행 상황도 공유해야 하나?
# AI: 맞습니다. 프로젝트 X의 최근 진행 상황과 주요 이슈에 대해 간략히 공유하고 논의할 예정이에요. 진행 상황을 미리 정리해 두는 게 좋겠습니다.
# Human: 최근에 이야기 나눴던 새로운 디자인에 대한 업데이트는 있어?
# AI: 네, 최근 새로운 디자인 시안이 나왔습니다. 주요 변경 사항으로는 컬러 팔레트가 좀 더 현대적인 톤으로 바뀌었고, UI 레이아웃도 보다 직관적으로 수정되었어요. 이번 회의에서 간략히 소개할 예정입니다.

# %%
from langchain_core.messages import SystemMessage, HumanMessage, AIMessage

# 요약 대상 대화 내용 추출 (마지막 Q&A 쌍 제외한 이전 내용)
messages = store[session].messages
if len(messages) > 2:
    original_dialog = "\n".join([f"{msg.type.upper()}: {msg.content}" for msg in messages[:-2]])
else:
    original_dialog = "\n".join([f"{msg.type.upper()}: {msg.content}" for msg in messages])

# LLM으로 요약 생성
summary_text = summary_chain.invoke({"conversation": original_dialog})
print("=== 요약 내용 ===")
print(summary_text)

# 기존 메모리를 요약으로 교체: 이전 내용 요약본 + 최근 Q&A 유지
new_history = InMemoryChatMessageHistory()
new_history.messages.append(SystemMessage(content=f"요약: {summary_text}"))
# 최근 대화의 마지막 Q&A 쌍 복원
if len(messages) >= 2:
    last_user_msg = messages[-2]
    last_ai_msg = messages[-1]
    if isinstance(last_user_msg, HumanMessage):
        new_history.add_user_message(last_user_msg.content)
    else:
        new_history.messages.append(last_user_msg)  # 혹시 시스템 메시지 등일 경우 직접 추가
    if isinstance(last_ai_msg, AIMessage):
        new_history.add_ai_message(last_ai_msg.content)
    else:
        new_history.messages.append(last_ai_msg)
# 메모리 교체
store[session] = new_history
# Out:
# 16:41:54 httpx INFO   HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# === 요약 내용 ===
# 오늘은 내일 오전 10시 회의를 위해 자료를 준비하고 검토하는 것이 계획이었으며, 참석자는 김 팀장님, 이 과장님, 최 대리님입니다. 프로젝트 X의 진행 상황도 공유할 예정입니다.

# %%
print(f"요약 후 user_a 메모리 메시지 개수: {len(store[session].messages)}")
print(store[session])
# Out:
# 요약 후 user_a 메모리 메시지 개수: 3
# System: 요약: 오늘은 내일 오전 10시 회의를 위해 자료를 준비하고 검토하는 것이 계획이었으며, 참석자는 김 팀장님, 이 과장님, 최 대리님입니다. 프로젝트 X의 진행 상황도 공유할 예정입니다.
# Human: 최근에 이야기 나눴던 새로운 디자인에 대한 업데이트는 있어?
# AI: 네, 최근 새로운 디자인 시안이 나왔습니다. 주요 변경 사항으로는 컬러 팔레트가 좀 더 현대적인 톤으로 바뀌었고, UI 레이아웃도 보다 직관적으로 수정되었어요. 이번 회의에서 간략히 소개할 예정입니다.

# %%
follow_up = "그럼 회의 전에 무엇을 더 준비해야 할까?"
response = chatbot.invoke({"question": follow_up}, config={"configurable": {"session_id": session}})
print(f"[{session}] 사용자: {follow_up}")
print(f"[{session}] 챗봇: {response}")
# Out:
# 16:48:17 httpx INFO   HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# [user_c] 사용자: 그럼 회의 전에 무엇을 더 준비해야 할까?
# [user_c] 챗봇: 회의 전에 준비하셔야 할 사항은 다음과 같습니다:
#
# 1. 새로운 디자인 시안에 대한 상세 자료 검토: 변경된 내용과 주요 포인트를 숙지하세요.
# 2. 피드백 및 질문 목록 작성: 디자인에 대해 궁금한 점이나 개선 요청이 있다면 미리 정리해두세요.
# 3. 프로젝트 X 진행 상황 자료 업데이트: 최신 진행 상황과 관련 이슈를 정리해두면 좋습니다.
# 4. 발표 자료 또는 참고 자료 준비: 필요 시 발표용 슬라이드나 참고 자료를 준비하세요.
# 5. 참석자와의 사전 의견 교환: 팀원들과 디자인에 대한 의견을 나누어 정리하면 회의가 원활하게 진행됩니다.
#
# 혹시 더 구체적인 도움이나 자료 준비가 필요하시면 말씀해 주세요!
