# %%
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
import os

OPENAI_API_KEY = os.getenv("OPENAI_API_KEY")
OPENAI_LLM_MODEL = os.getenv("OPENAI_LLM_MODEL")
OPENAI_EMBEDDING_MODEL = os.getenv("OPENAI_EMBEDDING_MODEL")
PINECONE_API_KEY = os.getenv("PINECONE_API_KEY")
PINECONE_ENVIRONMENT = os.getenv("PINECONE_ENVIRONMENT")
PINECONE_INDEX_REGION = os.getenv("PINECONE_INDEX_REGION")
PINECONE_INDEX_CLOUD = os.getenv("PINECONE_INDEX_CLOUD")
PINECONE_INDEX_NAME = os.getenv("PINECONE_INDEX_NAME")
PINECONE_INDEX_METRIC = os.getenv("PINECONE_INDEX_METRIC")
PINECONE_INDEX_DIMENSION = int(os.getenv("PINECONE_INDEX_DIMENSION"))

# %%
from pinecone import Pinecone, ServerlessSpec

pc = Pinecone(
    api_key=PINECONE_API_KEY
)

pc.create_index(
    name=PINECONE_INDEX_NAME,
    dimension=PINECONE_INDEX_DIMENSION,
    metric=PINECONE_INDEX_METRIC,
    spec=ServerlessSpec(
        region=PINECONE_INDEX_REGION,
        cloud=PINECONE_INDEX_CLOUD
    )
)

# %%
wine_index = pc.Index(PINECONE_INDEX_NAME)
wine_index.describe_index_stats()
# Out:
# {'dimension': 1536,
#  'index_fullness': 0.0,
#  'metric': 'cosine',
#  'namespaces': {},
#  'total_vector_count': 0,
#  'vector_type': 'dense'}

# %%
from langchain_community.document_loaders import CSVLoader

loader = CSVLoader("./winemag-data-130k-v2.csv", encoding="utf-8")
docs = loader.load()

docs[0]
# Out:
# Document(metadata={'source': './winemag-data-130k-v2.csv', 'row': 0}, page_content=": 0\ncountry: Italy\ndescription: Aromas include tropical fruit, broom, brimstone and dried herb. The palate isn't overly expressive, offering unripened apple, citrus and dried sage alongside brisk acidity.\ndesignation: Vulkà Bianco\npoints: 87\nprice: \nprovince: Sicily & Sardinia\nregion_1: Etna\nregion_2: \ntaster_name: Kerin O’Keefe\ntaster_twitter_handle: @kerinokeefe\ntitle: Nicosia 2013 Vulkà Bianco  (Etna)\nvariety: White Blend\nwinery: Nicosia")

# %%
print(len(docs))
print(max(len(doc.page_content) for doc in docs))
# Out:
# 129971
# 1115

# %%
from langchain_openai import OpenAIEmbeddings

embedding = OpenAIEmbeddings(model=OPENAI_EMBEDDING_MODEL, openai_api_key=OPENAI_API_KEY)

# %%
from langchain_pinecone import PineconeVectorStore

BATCH_SIZE = 300
for i in range(0, len(docs), BATCH_SIZE):
    batch = docs[i:i + BATCH_SIZE]
    try:
        PineconeVectorStore.from_documents(
            documents=batch,
            index_name=PINECONE_INDEX_NAME,
            embedding=embedding
        )

        print(f"{i}~{i+len(batch)-1} documents indexed")
    except Exception as e:
        print(f"Error indexing documents {i}~{i+len(batch)-1}: {e}")
# Out:
# 0~299 documents indexed
# 300~599 documents indexed
# 600~899 documents indexed
# 900~1199 documents indexed
# 1200~1499 documents indexed
# 1500~1799 documents indexed
# 1800~2099 documents indexed
# 2100~2399 documents indexed
# 2400~2699 documents indexed
# 2700~2999 documents indexed
# 3000~3299 documents indexed
# 3300~3599 documents indexed
# 3600~3899 documents indexed
# 3900~4199 documents indexed
# 4200~4499 documents indexed
# 4500~4799 documents indexed
# 4800~5099 documents indexed
# 5100~5399 documents indexed
# 5400~5699 documents indexed
# 5700~5999 documents indexed
# 6000~6299 documents indexed
# 6300~6599 documents indexed
# 6600~6899 documents indexed
# 6900~7199 documents indexed
# 7200~7499 documents indexed
# 7500~7799 documents indexed
# 7800~8099 documents indexed
# 8100~8399 documents indexed
# 8400~8699 documents indexed
# 8700~8999 documents indexed
# 9000~9299 documents indexed
# 9300~9599 documents indexed
# 9600~9899 documents indexed
# 9900~10199 documents indexed
# 10200~10499 documents indexed
# 10500~10799 documents indexed
# 10800~11099 documents indexed
# 11100~11399 documents indexed
# 11400~11699 documents indexed
# 11700~11999 documents indexed
# 12000~12299 documents indexed
# 12300~12599 documents indexed
# 12600~12899 documents indexed
# 12900~13199 documents indexed
# 13200~13499 documents indexed
# 13500~13799 documents indexed
# 13800~14099 documents indexed
# 14100~14399 documents indexed
# 14400~14699 documents indexed
# 14700~14999 documents indexed
# 15000~15299 documents indexed
# 15300~15599 documents indexed
# 15600~15899 documents indexed
# 15900~16199 documents indexed
# 16200~16499 documents indexed
# 16500~16799 documents indexed
# 16800~17099 documents indexed
# 17100~17399 documents indexed
# 17400~17699 documents indexed
# 17700~17999 documents indexed
# 18000~18299 documents indexed
# 18300~18599 documents indexed
# 18600~18899 documents indexed
# 18900~19199 documents indexed
# 19200~19499 documents indexed
# 19500~19799 documents indexed
# 19800~20099 documents indexed
# 20100~20399 documents indexed
# 20400~20699 documents indexed
# 20700~20999 documents indexed
# 21000~21299 documents indexed
# 21300~21599 documents indexed
# 21600~21899 documents indexed
# 21900~22199 documents indexed
# 22200~22499 documents indexed
# 22500~22799 documents indexed
# 22800~23099 documents indexed
# 23100~23399 documents indexed
# 23400~23699 documents indexed
# 23700~23999 documents indexed
# 24000~24299 documents indexed
# 24300~24599 documents indexed
# 24600~24899 documents indexed
# 24900~25199 documents indexed
# 25200~25499 documents indexed
# 25500~25799 documents indexed
# 25800~26099 documents indexed
# 26100~26399 documents indexed
# 26400~26699 documents indexed
# 26700~26999 documents indexed
# 27000~27299 documents indexed
# 27300~27599 documents indexed
# 27600~27899 documents indexed
# 27900~28199 documents indexed
# 28200~28499 documents indexed
# 28500~28799 documents indexed
# 28800~29099 documents indexed
# 29100~29399 documents indexed
# 29400~29699 documents indexed
# 29700~29999 documents indexed
# 30000~30299 documents indexed
# 30300~30599 documents indexed
# 30600~30899 documents indexed
# 30900~31199 documents indexed
# 31200~31499 documents indexed
# 31500~31799 documents indexed
# 31800~32099 documents indexed
# 32100~32399 documents indexed
# 32400~32699 documents indexed
# 32700~32999 documents indexed
# 33000~33299 documents indexed
# 33300~33599 documents indexed
# 33600~33899 documents indexed
# 33900~34199 documents indexed
# 34200~34499 documents indexed
# 34500~34799 documents indexed
# 34800~35099 documents indexed
# 35100~35399 documents indexed
# 35400~35699 documents indexed
# 35700~35999 documents indexed
# 36000~36299 documents indexed
# 36300~36599 documents indexed
# 36600~36899 documents indexed
# 36900~37199 documents indexed
# 37200~37499 documents indexed
# 37500~37799 documents indexed
# 37800~38099 documents indexed
# 38100~38399 documents indexed
# 38400~38699 documents indexed
# 38700~38999 documents indexed
# 39000~39299 documents indexed
# 39300~39599 documents indexed
# 39600~39899 documents indexed
# 39900~40199 documents indexed
# 40200~40499 documents indexed
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[12], line 7
#       5 batch = docs[i:i + BATCH_SIZE]
#       6 try:
# ----> 7     PineconeVectorStore.from_documents(
#       8         documents=batch,
#       9         index_name=PINECONE_INDEX_NAME,
#      10         embedding=embedding
#      11     )
#      13     print(f"{i}~{i+len(batch)-1} documents indexed")
#      14 except Exception as e:
#
# File c:\Users\511-00\miniconda3\envs\langchain_part_2\Lib\site-packages\langchain_core\vectorstores\base.py:848, in VectorStore.from_documents(cls, documents, embedding, **kwargs)
#     845     if any(ids):
#     846         kwargs["ids"] = ids
# --> 848 return cls.from_texts(texts, embedding, metadatas=metadatas, **kwargs)
#
# File c:\Users\511-00\miniconda3\envs\langchain_part_2\Lib\site-packages\langchain_pinecone\vectorstores.py:823, in PineconeVectorStore.from_texts(cls, texts, embedding, metadatas, ids, batch_size, text_key, namespace, index_name, upsert_kwargs, pool_threads, embeddings_chunk_size, id_prefix, **kwargs)
#     820 pinecone_index = cls.get_pinecone_index(index_name, pool_threads)
#     821 pinecone = cls(pinecone_index, embedding, text_key, namespace, **kwargs)
# --> 823 pinecone.add_texts(
#     824     texts,
#     825     metadatas=metadatas,
#     826     ids=ids,
#     827     namespace=namespace,
#     828     batch_size=batch_size,
#     829     embedding_chunk_size=embeddings_chunk_size,
#     830     id_prefix=id_prefix,
#     831     **(upsert_kwargs or {}),
#     832 )
#     833 return pinecone
#
# File c:\Users\511-00\miniconda3\envs\langchain_part_2\Lib\site-packages\langchain_pinecone\vectorstores.py:314, in PineconeVectorStore.add_texts(self, texts, metadatas, ids, namespace, batch_size, embedding_chunk_size, id_prefix, **kwargs)
#     312     embeddings = self._embedding.embed_documents(chunk_texts)
#     313     vector_tuples = list(zip(chunk_ids, embeddings, chunk_metadatas))
# --> 314     self.index.upsert(
#     315         vectors=vector_tuples,
#     316         namespace=namespace,
#     317         **kwargs,
#     318     )
#     320 return ids
#
# File c:\Users\511-00\miniconda3\envs\langchain_part_2\Lib\site-packages\pinecone\utils\error_handling.py:11, in validate_and_convert_errors.<locals>.inner_func(*args, **kwargs)
#       8 @wraps(func)
#       9 def inner_func(*args, **kwargs):
#      10     try:
# ---> 11         return func(*args, **kwargs)
#      12     except MaxRetryError as e:
#      13         if isinstance(e.reason, ProtocolError):
#
# File c:\Users\511-00\miniconda3\envs\langchain_part_2\Lib\site-packages\pinecone\data\index.py:141, in Index.upsert(self, vectors, namespace, batch_size, show_progress, **kwargs)
#     134     raise ValueError(
#     135         "async_req is not supported when batch_size is provided."
#     136         "To upsert in parallel, please follow: "
#     137         "https://docs.pinecone.io/docs/insert-data#sending-upserts-in-parallel"
#     138     )
#     140 if batch_size is None:
# --> 141     return self._upsert_batch(vectors, namespace, _check_type, **kwargs)
#     143 if not isinstance(batch_size, int) or batch_size <= 0:
#     144     raise ValueError("batch_size must be a positive integer")
#
# File c:\Users\511-00\miniconda3\envs\langchain_part_2\Lib\site-packages\pinecone\data\index.py:168, in Index._upsert_batch(self, vectors, namespace, _check_type, **kwargs)
#     158 def _upsert_batch(
#     159     self,
#     160     vectors: Union[
#    (...)    165     **kwargs,
#     166 ) -> UpsertResponse:
#     167     return self._vector_api.upsert_vectors(
# --> 168         IndexRequestFactory.upsert_request(vectors, namespace, _check_type, **kwargs),
#     169         **self._openapi_kwargs(kwargs),
#     170     )
#
# File c:\Users\511-00\miniconda3\envs\langchain_part_2\Lib\site-packages\pinecone\data\request_factory.py:93, in IndexRequestFactory.upsert_request(vectors, namespace, _check_type, **kwargs)
#      89 def vec_builder(v):
#      90     return VectorFactory.build(v, check_type=_check_type)
#      92 return UpsertRequest(
# ---> 93     vectors=list(map(vec_builder, vectors)),
#      94     **args_dict,
#      95     _check_type=_check_type,
#      96     **non_openapi_kwargs(kwargs),
#      97 )
#
# File c:\Users\511-00\miniconda3\envs\langchain_part_2\Lib\site-packages\pinecone\data\request_factory.py:90, in IndexRequestFactory.upsert_request.<locals>.vec_builder(v)
#      89 def vec_builder(v):
# ---> 90     return VectorFactory.build(v, check_type=_check_type)
#
# File c:\Users\511-00\miniconda3\envs\langchain_part_2\Lib\site-packages\pinecone\data\vector_factory.py:48, in VectorFactory.build(item, check_type)
#      46     return OpenApiVector(**args)
#      47 elif isinstance(item, tuple):
# ---> 48     return VectorFactory._tuple_to_vector(item, check_type)
#      49 elif isinstance(item, Mapping):
#      50     return VectorFactory._dict_to_vector(item, check_type)
#
# File c:\Users\511-00\miniconda3\envs\langchain_part_2\Lib\site-packages\pinecone\data\vector_factory.py:64, in VectorFactory._tuple_to_vector(item, check_type)
#      60     raise ValueError(
#      61         "Sparse values are not supported in tuples. Please use either dicts or OpenApiVector objects as inputs."
#      62     )
#      63 else:
# ---> 64     return OpenApiVector(
#      65         id=id,
#      66         values=convert_to_list(values),
#      67         metadata=metadata or {},
#      68         _check_type=check_type,
#      69     )
#
# File c:\Users\511-00\miniconda3\envs\langchain_part_2\Lib\site-packages\pinecone\openapi_support\model_utils.py:37, in convert_js_args_to_python_args.<locals>.wrapped_init(_self, *args, **kwargs)
#      33 if spec_property_naming:
#      34     kwargs = change_keys_js_to_python(
#      35         kwargs, _self if isinstance(_self, type) else _self.__class__
#      36     )
# ---> 37 return fn(_self, *args, **kwargs)
#
# File c:\Users\511-00\miniconda3\envs\langchain_part_2\Lib\site-packages\pinecone\core\openapi\db_data\model\vector.py:284, in Vector.__init__(self, id, *args, **kwargs)
#     276 if (
#     277     var_name not in self.attribute_map
#     278     and self._configuration is not None
#    (...)    281 ):
#     282     # discard variable.
#     283     continue
# --> 284 setattr(self, var_name, var_value)
#     285 if var_name in self.read_only_vars:
#     286     raise PineconeApiAttributeError(
#     287         f"`{var_name}` is a read-only attribute. Use `from_openapi_data` to instantiate "
#     288         f"class with read only attributes."
#     289     )
#
# File c:\Users\511-00\miniconda3\envs\langchain_part_2\Lib\site-packages\pinecone\openapi_support\model_utils.py:164, in OpenApiModel.__setattr__(self, attr, value)
#     162 def __setattr__(self, attr, value):
#     163     """set the value of an attribute using dot notation: `instance.attr = val`"""
# --> 164     self[attr] = value
#
# File c:\Users\511-00\miniconda3\envs\langchain_part_2\Lib\site-packages\pinecone\openapi_support\model_utils.py:449, in ModelNormal.__setitem__(self, name, value)
#     446     self.__dict__[name] = value
#     447     return
# --> 449 self.set_attribute(name, value)
#
# File c:\Users\511-00\miniconda3\envs\langchain_part_2\Lib\site-packages\pinecone\openapi_support\model_utils.py:140, in OpenApiModel.set_attribute(self, name, value)
#     135     raise PineconeApiTypeError(
#     136         error_msg, path_to_item=path_to_item, valid_classes=(str,), key_type=True
#     137     )
#     139 if self._check_type:
# --> 140     value = validate_and_convert_types(
#     141         value,
#     142         required_types_mixed,
#     143         path_to_item,
#     144         self._spec_property_naming,
#     145         self._check_type,
#     146         configuration=self._configuration,
#     147     )
#     148 if (name,) in self.allowed_values:
#     149     check_allowed_values(self.allowed_values, (name,), value)
#
# File c:\Users\511-00\miniconda3\envs\langchain_part_2\Lib\site-packages\pinecone\openapi_support\model_utils.py:1539, in validate_and_convert_types(input_value, required_types_mixed, path_to_item, spec_property_naming, _check_type, configuration)
#    1537         inner_path = list(path_to_item)
#    1538         inner_path.append(index)
# -> 1539         input_value[index] = validate_and_convert_types(
#    1540             inner_value,
#    1541             inner_required_types,
#    1542             inner_path,
#    1543             spec_property_naming,
#    1544             _check_type,
#    1545             configuration=configuration,
#    1546         )
#    1547 elif isinstance(input_value, dict):
#    1548     if input_value == {}:
#    1549         # allow an empty dict
#
# KeyboardInterrupt:

# %%
vector_store = PineconeVectorStore(
    index_name=PINECONE_INDEX_NAME,
    embedding=embedding
)

query = "달콤한 맛을 가진 와인"
results = vector_store.similarity_search(query, k=5)
for result in results:
    print(f"{result.page_content[:100]}...\n")
# Out:
# : 11089
# country: US
# description: Ripe hay, vanilla, and apricot mark the nose; deep orange flavors w...
#
# : 6319
# country: US
# description: Aromas of candy corn, spice and almond butter are followed by full-b...
#
# : 7687
# country: US
# description: Smoothly seductive in bright red-berry and pomegranate fruit, this y...
#
# : 21687
# country: US
# description: Luscious aromas of lemon, sweet orange and honey are followed by a ...
#
# : 10299
# country: US
# description: High on the deliciousness-factor, this shows soft, seemingly sweet ...
